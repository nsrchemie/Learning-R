# %%
library(dplyr)
library(UsingR)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:Hmisc':
#
#     combine, src, summarize
#
# The following object is masked from 'package:MASS':
#
#     select
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
#Unlike a lot of the data we've seen so far, data is not always
#normally distributed.  Let's look at CEO compensation in 2000
mypar(1,2)
hist(exec.pay)
qqnorm(exec.pay)
qqline(exec.pay)
# Out:
# Error in eval(expr, envir, enclos): could not find function "mypar"
# Plot with title "Histogram of exec.pay"
# Plot with title "Normal Q-Q Plot"

# %%
#Computing three percentiles is useful (25,50(median),75)
#Useful for viewing outliers
boxplot(exec.pay, ylab='10,000s of dollars', ylim=c(0,400))
# Out:
# plot without title
